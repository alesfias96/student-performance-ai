# %% [markdown]
# # 01 — Dataset generation
#
# Generiamo i CSV sintetici in `data/raw/` usando `src.data_generation`.

# %%
from pathlib import Path
import pandas as pd

# Esegui generazione dataset
# !python -m src.data_generation

# Carica e mostra un esempio
answers = pd.read_csv("~/Desktop/student-performance-ai/data/raw/student_answers.csv")
questions = pd.read_csv("~/Desktop/student-performance-ai/data/raw/questions_bank.csv")

answers.head(), questions.head()
# Out:
# /Users/alessandrofiaschini/myenv/bin/python: Error while finding module specification for 'src.data_generation' (ModuleNotFoundError: No module named 'src')
# (     student_id  test_id   question_id            topic           subskill  \
#  0  student_0001  test_01  test_01_q_01          Algebra  equazioni_lineari
#  1  student_0001  test_01  test_01_q_02         Derivate        regole_base
#  2  student_0001  test_01  test_01_q_03         Derivate             catena
#  3  student_0001  test_01  test_01_q_04  Fisica_Dinamica            attrito
#  4  student_0001  test_01  test_01_q_05         Derivate           prodotto
#
#     difficulty  correct_answer  answer_given  is_correct error_type  \
#  0           4           13.75         13.75           1       none
#  1           4            0.24         -0.24           0      segno
#  2           4            8.42          5.93           0    formula
#  3           1            5.73          5.73           1       none
# ...

# %%
# Dimensioni dataset
print("answers:", answers.shape)
print("questions:", questions.shape)

# Quanti studenti?
print("n_students:", answers["student_id"].nunique())

# Quanti topic?
print("topics:", sorted(answers["topic"].unique()))
# Out:
# answers: (15000, 12)
# questions: (75, 6)
# n_students: 200
# topics: ['Algebra', 'Derivate', 'Fisica_Dinamica', 'Fisica_Energia', 'Funzioni']
