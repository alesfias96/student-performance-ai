# %% [markdown]
# # 04 — Report demo
#
# Generiamo scoring + report per uno studente e apriamo l'HTML.

# %%
import pandas as pd

# Esegui pipeline completa (scoring + report)
# !python -m src.main --score --report --student-id student_0001

# Controlla i file generati
import os, glob
sorted(glob.glob("reports/report_*.html"))[:5]
# Out:
# /Users/alessandrofiaschini/myenv/bin/python: Error while finding module specification for 'src.main' (ModuleNotFoundError: No module named 'src')
# []

# %%
# Leggi le metriche processate
topic_scores = pd.read_csv("~/Desktop/student-performance-ai/data/processed/student_topic_scores.csv")
overall = pd.read_csv("~/Desktop/student-performance-ai/data/processed/student_overall_summary.csv")
topic_scores[topic_scores["student_id"]=="student_0001"].sort_values("topic_accuracy")
# Out:
#      student_id            topic  topic_n_questions  topic_accuracy  \
# 2  student_0001  Fisica_Dinamica                 12          0.5833
# 1  student_0001         Derivate                 21          0.6190
# 4  student_0001         Funzioni                 16          0.6250
# 3  student_0001   Fisica_Energia                 18          0.7222
# 0  student_0001          Algebra                  8          0.7500
#
#    topic_avg_time_seconds  topic_avg_confidence
# 2                   31.57                  3.00
# 1                   32.38                  2.62
# 4                   34.26                  3.62
# 3                   32.62                  2.72
# 0                   21.98                  3.75

# %% [markdown]
# Apri manualmente il file `reports/report_student_0001.html` nel browser.
